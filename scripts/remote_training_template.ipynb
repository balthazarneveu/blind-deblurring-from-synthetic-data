# %%
exp = !!!exp!!!
branch = !!!branch!!!
git_user = !!!git_user!!!
git_repo = !!!git_repo!!!
wandb_flag = !!!wandb_flag!!!
output_dir = !!!output_dir!!!
dataset_files = !!!dataset_files!!!
train_script = !!!train_script!!!

# %% [markdown]
# # Clone git repo

# %%
# %cd ~
# !git clone https://github.com/$git_user/$git_repo >/dev/null
# %cd $git_repo
# !git checkout $branch
# !pip install -e .

# %% [markdown]
# # Load Kaggle datasets

# %%
# !mkdir __dataset/deadleaves_div2k_512
# !cp /kaggle/input/deadleaves-div2k-512/deadleaves_div2k_512/* "__dataset/deadleaves_div2k_512"

# %%
# !mkdir __dataset/div2k
# !cp -r "/kaggle/input/div2k-dataset/DIV2K_train_HR" "__dataset/div2k/"
# !cp -r "/kaggle/input/div2k-dataset/DIV2K_valid_HR/" "__dataset/div2k/"

# %% [markdown]
# # Setup weights and biases

# %%
if wandb_flag:
    from kaggle_secrets import UserSecretsClient
    user_secrets = UserSecretsClient()
    wandb_api_key = user_secrets.get_secret("wandb_api_key")

    # !pip install wandb >/dev/null
    # !wandb login $wandb_api_key

# %% [markdown]
# # Launch training

# %%
exp_str = ' '.join([str(e) for e in exp])
wb_ext = "-nowb" if not wandb_flag else ""
# !python $train_script -e $exp_str $wb_ext

# %% [markdown]
# # Prepare outputs

# %%
if output_dir is not None:
    # !tar -cvzf /kaggle/working/output.tgz $output_dir
